# %%
import pandas as pd

df = pd.read_csv("USA B2B EMAIL DATABASE PART 1 .csv")

# %%
df.columns
# Out:
# Index(['BUSINESS NAME', 'MAILING ADDRESS', 'MAILING CITY', 'MAILING STATE',
#        'MAILING ZIP', 'AREA CODE AND PHONE', 'FAX', 'SALES VOLUME',
#        'NUMBER OF EMPLOYEES', 'PUBLIC PRIVATE COMPANY', 'LOCATION TYPE',
#        'FIRM INDIVIDUAL', 'CREDIT SCORE CODE', 'STOCK EXCHANGE',
#        'STOCK TICKER SYMBOL', 'WEB ADDRESS', 'FIRSTNAME', 'LASTNAME', 'TITLE',
#        'EMAIL', 'SIC NAME1', 'SIC', 'NAICS', 'NCCI', 'CA WC', 'DE WC', 'PA WC',
#        'MI WC', 'NJ WC', 'NY WC', 'TX WC', 'ISO CGL'],
#       dtype='object')

# %%
df.head()
# Out:
#                     BUSINESS NAME      MAILING ADDRESS MAILING CITY  \
# 0                    MANPOWER INC    100 W MANPOWER PL    MILWAUKEE
# 1                 KANGAROO BRANDS       7620 N 81ST ST    MILWAUKEE
# 2         OLYMPIA SCHOOL DISTRICT   1113 LEGION WAY SE      OLYMPIA
# 3                CAT RENTAL STORE  601 W WASHINGTON ST  EAST PEORIA
# 4  UNIVERSITY-AR-MEDICAL SCIENCES    4301 W MARKHAM ST  LITTLE ROCK
#
#   MAILING STATE MAILING ZIP  AREA CODE AND PHONE           FAX  \
# 0            WI  53212-4030         4.149611e+09  414-961-6027
# 1            WI  53223-3836         4.143621e+09  414-355-4295
# 2            WA  98501-1697         3.605966e+09  360-596-6111
# 3            IL  61611-2033         3.096950e+09  309-694-3409
# 4            AR  72205-7199         5.016867e+09           NaN
#
#         SALES VOLUME NUMBER OF EMPLOYEES PUBLIC PRIVATE COMPANY  ...  \
# 0   $16,038,700,000               30,000                 PUBLIC  ...
# ...
