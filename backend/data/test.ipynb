# %%
import pandas as pd

df = pd.read_csv("business_dataset.csv")

# %%
df.columns
# Out:
# Index(['BUSINESS NAME', 'MAILING ADDRESS', 'MAILING CITY', 'MAILING STATE',
#        'MAILING ZIP', 'AREA CODE AND PHONE', 'FAX', 'SALES VOLUME',
#        'NUMBER OF EMPLOYEES', 'PUBLIC PRIVATE COMPANY', 'LOCATION TYPE',
#        'FIRM INDIVIDUAL', 'CREDIT SCORE CODE', 'STOCK EXCHANGE',
#        'STOCK TICKER SYMBOL', 'WEB ADDRESS', 'FIRSTNAME', 'LASTNAME', 'TITLE',
#        'EMAIL', 'SIC NAME1', 'SIC', 'NAICS', 'NCCI', 'CA WC', 'DE WC', 'PA WC',
#        'MI WC', 'NJ WC', 'NY WC', 'TX WC', 'ISO CGL'],
#       dtype='object')

# %%
df['SIC NAME1'].nunique()
# Out:
# 5984

# %%
import pandas as pd
df = pd.read_excel("Influencer_Marketing_130_Screens_Full.xlsx",sheet_name=1)
df
# Out:
#     Screen ID              Screen Name  \
# 0          11       Brand Registration
# 1          12    Business Verification
# 2          13            Brand Profile
# 3          14        Brand Preferences
# 4          15          Brand Dashboard
# 5          16          Create Campaign
# 6          17       Campaign Objective
# 7          18          Target Audience
# 8          19       Platform Selection
# 9          20        Budget Allocation
# 10         21        Campaign Timeline
# 11         22     Content Brief Upload
# 12         23                CTA Setup
# 13         24          Campaign Review
# 14         25       Campaign Submitted
# 15         26         Active Campaigns
# 16         27       Upcoming Campaigns
# 17         28      Completed Campaigns
# 18         29   Influencer Marketplace
# 19         30       Influencer Filters
# 20         31  Influencer Profile View
# 21         32  Shortlisted Influencers
# 22         33        Invite Influencer
# ...

# %%
df.columns
# Out:
# Index(['Screen ID', 'Screen Name', 'Detailed Description'], dtype='object')
